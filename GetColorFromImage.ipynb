# %%
import cv2
import numpy as np
from os import walk
imageFileNames = []
for (dirpath, dirnames, filenames) in walk("CropImageOutput"):
    imageFileNames.extend(filenames)
    break
class ColorDetection:
    
    def __init__(self):
        self.TARGET_COLORS = {"Red": (255, 0, 0), "White": (255, 255, 255), "Blue": (0, 0, 255), "Black":(0,0,0), "Silver":(192,192,192)}
    
    def color_difference (self,color1, color2):
        return sum([abs(component1-component2) for component1, component2 in zip(color1, color2)])
    
    def get_dominant_color(self,color):
        differences = [[self.color_difference(color, target_value), target_name] for target_name, target_value in self.TARGET_COLORS.items()]
        differences.sort()
        return differences[0][1]
    
    def color_detector1(self,img):
        data = np.reshape(img, (-1,3))
        data = np.float32(data)
        criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
        flags = cv2.KMEANS_RANDOM_CENTERS
        compactness,labels,centers = cv2.kmeans(data,1,None,criteria,10,flags)
        return tuple(centers[0].astype(np.int32))
    
    def color_detector2(self,img):
        colors, count = np.unique(img.reshape(-1,img.shape[-1]), axis=0, return_counts=True)
        return tuple(colors[count.argmax()])
    
    def color_detector3(self,img):
        avg_color_per_row = np.average(img, axis=0)
        avg_color = np.average(avg_color_per_row, axis=0)
        return tuple(avg_color)
    
    def get_prominent_color(self,filename):
        img = cv2.imread('CropImageOutput/' + file)
        vals = []
        vals.append(self.get_dominant_color(self.color_detector1(img)))
        vals.append(self.get_dominant_color(self.color_detector2(img)))
        vals.append(self.get_dominant_color(self.color_detector3(img)))
        color_value = max(set(vals), key = vals.count) 
        return filename, color_value

# %%
colDetection = ColorDetection()

for file in imageFileNames:
    img = cv2.imread('CropImageOutput/' + file)
    print(colDetection.get_prominent_color('CropImageOutput/' + file))
# Out:
# ('CropImageOutput/1_image1.jpg', 'Silver')
# ('CropImageOutput/1_image10.jpg', 'Black')
# ('CropImageOutput/1_image100.jpg', 'Silver')
# ('CropImageOutput/1_image101.jpg', 'Silver')
# ('CropImageOutput/1_image102.jpg', 'Silver')
# ('CropImageOutput/1_image103.jpg', 'Silver')
# ('CropImageOutput/1_image104.jpg', 'Silver')
# ('CropImageOutput/1_image1041.jpg', 'Black')
# ('CropImageOutput/1_image1042.jpg', 'Black')
# ('CropImageOutput/1_image1043.jpg', 'Black')
# ('CropImageOutput/1_image1044.jpg', 'Black')
# ('CropImageOutput/1_image1045.jpg', 'Black')
# ('CropImageOutput/1_image1046.jpg', 'Black')
# ('CropImageOutput/1_image1047.jpg', 'Black')
# ('CropImageOutput/1_image1048.jpg', 'Black')
# ('CropImageOutput/1_image1049.jpg', 'Black')
# ('CropImageOutput/1_image105.jpg', 'Silver')
# ('CropImageOutput/1_image1050.jpg', 'Black')
# ('CropImageOutput/1_image1051.jpg', 'Black')
# ('CropImageOutput/1_image1052.jpg', 'Black')
# ('CropImageOutput/1_image1053.jpg', 'Black')
# ('CropImageOutput/1_image1054.jpg', 'Black')
# ('CropImageOutput/1_image1055.jpg', 'Black')
# ('CropImageOutput/1_image1056.jpg', 'Black')
# ('CropImageOutput/1_image1057.jpg', 'Black')
# ('CropImageOutput/1_image1058.jpg', 'Black')
# ('CropImageOutput/1_image1059.jpg', 'Black')
# ('CropImageOutput/1_image106.jpg', 'Silver')
# ('CropImageOutput/1_image1060.jpg', 'Black')
# ('CropImageOutput/1_image1061.jpg', 'Black')
# ('CropImageOutput/1_image1062.jpg', 'Black')
# ('CropImageOutput/1_image1063.jpg', 'Black')
# ('CropImageOutput/1_image1064.jpg', 'Black')
# ('CropImageOutput/1_image1065.jpg', 'Black')
# ('CropImageOutput/1_image1066.jpg', 'Black')
# ('CropImageOutput/1_image107.jpg', 'Silver')
# ('CropImageOutput/1_image108.jpg', 'Silver')
# ('CropImageOutput/1_image109.jpg', 'Silver')
# ('CropImageOutput/1_image11.jpg', 'Black')
# ('CropImageOutput/1_image110.jpg', 'Silver')
# ('CropImageOutput/1_image111.jpg', 'Silver')
# ('CropImageOutput/1_image1115.jpg', 'Silver')
# ('CropImageOutput/1_image1116.jpg', 'Silver')
# ('CropImageOutput/1_image1117.jpg', 'Silver')
# ('CropImageOutput/1_image1118.jpg', 'Black')
# ('CropImageOutput/1_image1119.jpg', 'Black')
# ('CropImageOutput/1_image112.jpg', 'Silver')
# ('CropImageOutput/1_image1120.jpg', 'Black')
# ('CropImageOutput/1_image1121.jpg', 'Black')
# ('CropImageOutput/1_image1122.jpg', 'Black')
# ('CropImageOutput/1_image1123.jpg', 'Black')
# ('CropImageOutput/1_image1124.jpg', 'Black')
# ('CropImageOutput/1_image1125.jpg', 'Black')
# ('CropImageOutput/1_image1126.jpg', 'Black')
# ('CropImageOutput/1_image1127.jpg', 'Black')
# ('CropImageOutput/1_image1128.jpg', 'Black')
# ('CropImageOutput/1_image1129.jpg', 'Black')
# ('CropImageOutput/1_image113.jpg', 'Silver')
# ('CropImageOutput/1_image1130.jpg', 'Black')
# ('CropImageOutput/1_image1131.jpg', 'Black')
# ('CropImageOutput/1_image1132.jpg', 'Black')
# ('CropImageOutput/1_image1133.jpg', 'Black')
# ('CropImageOutput/1_image1134.jpg', 'Black')
# ('CropImageOutput/1_image1135.jpg', 'Black')
# ('CropImageOutput/1_image1136.jpg', 'Black')
# ('CropImageOutput/1_image1137.jpg', 'Silver')
# ('CropImageOutput/1_image12.jpg', 'Black')
# ('CropImageOutput/1_image13.jpg', 'Black')
# ('CropImageOutput/1_image130.jpg', 'Silver')
# ('CropImageOutput/1_image131.jpg', 'Silver')
# ('CropImageOutput/1_image137.jpg', 'Silver')
# ('CropImageOutput/1_image138.jpg', 'Silver')
# ('CropImageOutput/1_image139.jpg', 'Black')
# ('CropImageOutput/1_image14.jpg', 'Black')
# ('CropImageOutput/1_image140.jpg', 'Black')
# ('CropImageOutput/1_image141.jpg', 'Black')
# ('CropImageOutput/1_image142.jpg', 'Black')
# ('CropImageOutput/1_image143.jpg', 'Black')
# ('CropImageOutput/1_image1436.jpg', 'Silver')
# ('CropImageOutput/1_image1437.jpg', 'Silver')
# ('CropImageOutput/1_image1438.jpg', 'Silver')
# ('CropImageOutput/1_image144.jpg', 'Black')
# ('CropImageOutput/1_image1440.jpg', 'Black')
# ('CropImageOutput/1_image1441.jpg', 'Black')
# ('CropImageOutput/1_image1442.jpg', 'Black')
# ('CropImageOutput/1_image1443.jpg', 'Black')
# ('CropImageOutput/1_image1444.jpg', 'Black')
# ('CropImageOutput/1_image1445.jpg', 'Black')
# ('CropImageOutput/1_image1446.jpg', 'Black')
# ('CropImageOutput/1_image1447.jpg', 'Black')
# ('CropImageOutput/1_image1448.jpg', 'Black')
# ('CropImageOutput/1_image1449.jpg', 'Black')
# ('CropImageOutput/1_image145.jpg', 'Black')
# ('CropImageOutput/1_image1450.jpg', 'Black')
# ('CropImageOutput/1_image1451.jpg', 'Black')
# ('CropImageOutput/1_image1452.jpg', 'Black')
# ('CropImageOutput/1_image1453.jpg', 'Black')
# ('CropImageOutput/1_image1454.jpg', 'Black')
# ('CropImageOutput/1_image1456.jpg', 'Black')
# ('CropImageOutput/1_image1457.jpg', 'Black')
# ('CropImageOutput/1_image1458.jpg', 'Black')
# ('CropImageOutput/1_image146.jpg', 'Black')
# ('CropImageOutput/1_image147.jpg', 'Black')
# ('CropImageOutput/1_image148.jpg', 'Black')
# ('CropImageOutput/1_image1484.jpg', 'Silver')
# ('CropImageOutput/1_image149.jpg', 'Black')
# ('CropImageOutput/1_image15.jpg', 'Black')
# ('CropImageOutput/1_image150.jpg', 'Black')
# ('CropImageOutput/1_image151.jpg', 'Black')
# ('CropImageOutput/1_image152.jpg', 'Black')
# ('CropImageOutput/1_image153.jpg', 'Black')
# ('CropImageOutput/1_image154.jpg', 'Black')
# ('CropImageOutput/1_image155.jpg', 'Black')
# ('CropImageOutput/1_image156.jpg', 'Black')
# ('CropImageOutput/1_image157.jpg', 'Black')
# ('CropImageOutput/1_image158.jpg', 'Black')
# ('CropImageOutput/1_image159.jpg', 'Black')
# ('CropImageOutput/1_image16.jpg', 'Black')
# ('CropImageOutput/1_image160.jpg', 'Black')
# ('CropImageOutput/1_image161.jpg', 'Black')
# ('CropImageOutput/1_image162.jpg', 'Black')
# ('CropImageOutput/1_image17.jpg', 'Black')
# ('CropImageOutput/1_image18.jpg', 'Black')
# ('CropImageOutput/1_image19.jpg', 'Black')
# ('CropImageOutput/1_image2.jpg', 'Silver')
# ('CropImageOutput/1_image20.jpg', 'Black')
# ('CropImageOutput/1_image21.jpg', 'Black')
# ('CropImageOutput/1_image22.jpg', 'Black')
# ('CropImageOutput/1_image3.jpg', 'Black')
# ('CropImageOutput/1_image4.jpg', 'Silver')
# ('CropImageOutput/1_image403.jpg', 'Silver')
# ('CropImageOutput/1_image404.jpg', 'Silver')
# ('CropImageOutput/1_image405.jpg', 'Silver')
# ('CropImageOutput/1_image406.jpg', 'Silver')
# ('CropImageOutput/1_image407.jpg', 'Silver')
# ('CropImageOutput/1_image408.jpg', 'Silver')
# ('CropImageOutput/1_image409.jpg', 'Silver')
# ('CropImageOutput/1_image410.jpg', 'Silver')
# ('CropImageOutput/1_image431.jpg', 'Silver')
# ('CropImageOutput/1_image496.jpg', 'Silver')
# ('CropImageOutput/1_image497.jpg', 'Silver')
# ('CropImageOutput/1_image498.jpg', 'Silver')
# ('CropImageOutput/1_image499.jpg', 'Silver')
# ('CropImageOutput/1_image5.jpg', 'Silver')
# ('CropImageOutput/1_image500.jpg', 'Silver')
# ('CropImageOutput/1_image501.jpg', 'Silver')
# ('CropImageOutput/1_image502.jpg', 'Silver')
# ('CropImageOutput/1_image503.jpg', 'Silver')
# ('CropImageOutput/1_image504.jpg', 'Silver')
# ('CropImageOutput/1_image505.jpg', 'Silver')
# ('CropImageOutput/1_image506.jpg', 'Silver')
# ('CropImageOutput/1_image507.jpg', 'Silver')
# ('CropImageOutput/1_image508.jpg', 'Silver')
# ('CropImageOutput/1_image509.jpg', 'Silver')
# ('CropImageOutput/1_image510.jpg', 'Silver')
# ('CropImageOutput/1_image511.jpg', 'Silver')
# ('CropImageOutput/1_image512.jpg', 'Silver')
# ('CropImageOutput/1_image513.jpg', 'Silver')
# ('CropImageOutput/1_image514.jpg', 'Silver')
# ('CropImageOutput/1_image515.jpg', 'Silver')
# ('CropImageOutput/1_image516.jpg', 'Silver')
# ('CropImageOutput/1_image517.jpg', 'Silver')
# ('CropImageOutput/1_image518.jpg', 'Silver')
# ('CropImageOutput/1_image519.jpg', 'Silver')
# ('CropImageOutput/1_image520.jpg', 'Silver')
# ('CropImageOutput/1_image521.jpg', 'Silver')
# ('CropImageOutput/1_image522.jpg', 'Silver')
# ('CropImageOutput/1_image55.jpg', 'Black')
# ('CropImageOutput/1_image575.jpg', 'Silver')
# ('CropImageOutput/1_image576.jpg', 'Silver')
# ('CropImageOutput/1_image577.jpg', 'Silver')
# ('CropImageOutput/1_image578.jpg', 'Silver')
# ('CropImageOutput/1_image58.jpg', 'Black')
# ('CropImageOutput/1_image581.jpg', 'Silver')
# ('CropImageOutput/1_image582.jpg', 'Silver')
# ('CropImageOutput/1_image583.jpg', 'Silver')
# ('CropImageOutput/1_image585.jpg', 'Silver')
# ('CropImageOutput/1_image586.jpg', 'Silver')
# ('CropImageOutput/1_image587.jpg', 'Silver')
# ('CropImageOutput/1_image588.jpg', 'Silver')
# ('CropImageOutput/1_image589.jpg', 'Silver')
# ('CropImageOutput/1_image59.jpg', 'Black')
# ('CropImageOutput/1_image590.jpg', 'Silver')
# ('CropImageOutput/1_image591.jpg', 'Silver')
# ('CropImageOutput/1_image592.jpg', 'Silver')
# ('CropImageOutput/1_image593.jpg', 'Silver')
# ('CropImageOutput/1_image594.jpg', 'Silver')
# ('CropImageOutput/1_image595.jpg', 'Silver')
# ('CropImageOutput/1_image596.jpg', 'Silver')
# ('CropImageOutput/1_image597.jpg', 'Silver')
# ('CropImageOutput/1_image598.jpg', 'Silver')
# ('CropImageOutput/1_image599.jpg', 'Silver')
# ('CropImageOutput/1_image6.jpg', 'Silver')
# ('CropImageOutput/1_image600.jpg', 'Silver')
# ('CropImageOutput/1_image601.jpg', 'Silver')
# ('CropImageOutput/1_image61.jpg', 'Black')
# ('CropImageOutput/2_image1120.jpg', 'Silver')
# ('CropImageOutput/2_image1121.jpg', 'Black')
# ('CropImageOutput/2_image1122.jpg', 'Black')
# ('CropImageOutput/2_image142.jpg', 'Black')
# ('CropImageOutput/2_image143.jpg', 'Black')
# ('CropImageOutput/2_image144.jpg', 'Black')
# ('CropImageOutput/2_image1442.jpg', 'Black')
# ('CropImageOutput/2_image146.jpg', 'Black')
# ('CropImageOutput/2_image147.jpg', 'Black')
# ('CropImageOutput/2_image504.jpg', 'Silver')
# ('CropImageOutput/2_image506.jpg', 'Silver')
